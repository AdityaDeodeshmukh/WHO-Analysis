# %% [markdown]
# <font size="5.5">Analysis of WHO Life Expectancy Dataset</font>

# %% [markdown]
# This is an analysis of data published by the Global Health Observatory (GHO) data repository under World Health Organization (WHO). The goal of this analysis is to find if correlation exists between the life expectancy of a country and various factors such as vaccinations, Alcohol consumption, Expendeture on Healthcare etc.

# %%
#importing all the needed modules
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Life Expectancy Data.csv")
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %% [markdown]
# Here we see that the mean life expectancy from 2000 to 2015 is 69.224932. Now, we shall analyse the mean and median life expectancy year by year from 2000 to 2015.

# %%
df1=df.copy()

# %%
df2=df1.groupby(by="Year").mean()
df2=df2["Life expectancy "]
df2
# Out:
# Year
# 2000    66.750273
# 2001    67.128962
# 2002    67.351366
# 2003    67.433333
# 2004    67.646448
# 2005    68.209290
# 2006    68.667760
# 2007    69.036066
# 2008    69.427869
# 2009    69.938251
# 2010    70.048634
# 2011    70.654098
# 2012    70.916940
# 2013    71.236066
# 2014    71.536612
# 2015    71.616940
# Name: Life expectancy , dtype: float64

# %%
plt.figure(figsize=(20,10),dpi=160)
df2.plot(kind="line")
plt.ylabel("Life expectancy ")
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %%
df2=df1.groupby(by="Year").median()
df2=df2["Life expectancy "]
df2
# Out:
# Year
# 2000    71.0
# 2001    71.2
# 2002    71.4
# 2003    71.1
# 2004    71.2
# 2005    71.6
# 2006    72.1
# 2007    72.4
# 2008    72.4
# 2009    72.6
# 2010    72.8
# 2011    73.3
# 2012    73.2
# 2013    73.2
# 2014    73.6
# 2015    73.9
# Name: Life expectancy , dtype: float64

# %%
plt.figure(figsize=(20,10),dpi=160)
df2.plot(kind="line")
plt.ylabel("Median Life expectancy ")
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# As we can see life expectancy, on average, has risen in the period of 2000 and 2015. The mean life expectancy has risen from 66.75 Years to 71.61 Years, which is a rise of About 7%. The median life expectancy has increased from 71 to 73.9, which is an increase of 4%

# %% [markdown]
# Now we shall perform analysis of other factors like adult mortality and infant deaths

# %%
df2=df1.groupby(by="Year").mean()
df2=df2[["Adult Mortality","infant deaths"]]
df2
# Out:
#       Adult Mortality  infant deaths
# Year
# 2000       181.475410      37.540984
# 2001       175.169399      36.825137
# 2002       171.437158      35.584699
# 2003       169.131148      34.874317
# 2004       186.262295      33.644809
# 2005       167.633880      32.366120
# 2006       170.404372      31.808743
# 2007       159.808743      30.612022
# 2008       174.519126      29.568306
# 2009       163.393443      28.956284
# 2010       161.863388      27.928962
# 2011       156.535519      26.830601
# 2012       148.792350      26.338798
# 2013       148.765027      23.968912
# 2014       148.688525      24.557377
# 2015       152.863388      23.803279

# %%
plt.figure(figsize=(20,10),dpi=160)
df2["Adult Mortality"].plot(kind="line")
plt.ylabel("Adult mortality")
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %%
plt.figure(figsize=(20,10),dpi=160)
df2["Adult Mortality"].plot(kind="line")
plt.ylabel("infant deaths")
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# As we can see the number of infant deaths(per 1000) as well as the Adult Mortality has decreased drastically

# %% [markdown]
# Now let us analyse the life expectancy for developed and developing countries seperately

# %%
df2=df[df["Status"]=="Developing"]
df2=df2.groupby(by="Year").mean()
df2[["Life expectancy ","Adult Mortality","infant deaths"]]
# Out:
#       Life expectancy   Adult Mortality  infant deaths
# Year
# 2000         64.619868       200.496689      45.119205
# 2001         65.009934       193.158940      44.258278
# 2002         65.190728       189.443709      42.761589
# 2003         65.206623       187.609272      41.913907
# 2004         65.370861       207.834437      40.423841
# 2005         66.009272       184.172185      38.887417
# 2006         66.450331       186.695364      38.211921
# 2007         66.860927       177.589404      36.768212
# 2008         67.413907       195.172185      35.516556
# 2009         67.894040       181.754967      34.788079
# 2010         67.908609       180.370861      33.562914
# 2011         68.523841       175.788079      32.231788
# 2012         68.898013       165.258278      31.649007
# 2013         69.234437       166.165563      28.484472
# 2014         69.501987       164.430464      29.496689
# 2015         69.690066       169.390728      28.596026

# %% [markdown]
# As we see, for developing countried, there is a significant increase in the life expectancy and a drastic decrease in adult mortality and the number of infant deaths(per 1000).

# %%
df2=df[df["Status"]=="Developed"]
df2=df2.groupby(by="Year").mean()
df2[["Life expectancy ","Adult Mortality","infant deaths"]]
# Out:
#       Life expectancy   Adult Mortality  infant deaths
# Year
# 2000         76.803125         91.71875        1.78125
# 2001         77.128125         90.28125        1.75000
# 2002         77.546875         86.46875        1.71875
# 2003         77.940625         81.93750        1.65625
# 2004         78.384375         84.46875        1.65625
# 2005         78.590625         89.59375        1.59375
# 2006         79.131250         93.53125        1.59375
# 2007         79.300000         75.90625        1.56250
# 2008         78.931250         77.06250        1.50000
# 2009         79.584375         76.75000        1.43750
# 2010         80.146875         74.53125        1.34375
# 2011         80.706250         65.68750        1.34375
# 2012         80.443750         71.09375        1.28125
# 2013         80.681250         66.65625        1.25000
# 2014         81.137500         74.40625        1.25000
# 2015         80.709375         74.87500        1.18750

# %% [markdown]
# We see a similar result when it comes to developed countries
