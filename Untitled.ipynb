# %%
import pandas as pd

# %%
df=pd.read_csv("spotify.csv")

# %%
df.corr()
# Out:
#                   Unnamed: 0  Beats per minute    Energy  Danceability  \
# Unnamed: 0          1.000000          0.073033  0.169256      0.065912
# Beats per minute    0.073033          1.000000  0.249641     -0.267712
# Energy              0.169256          0.249641  1.000000     -0.053185
# Danceability        0.065912         -0.267712 -0.053185      1.000000
# Loudness(in db)     0.126483          0.146231  0.812707      0.135421
# Liveness            0.205656          0.139327  0.308413     -0.132534
# Length(seconds)    -0.160972         -0.078129 -0.229985     -0.215240
# Speechiness         0.006643          0.356196 -0.015288      0.163593
# Positivity          0.130626          0.118553  0.549539      0.328999
# Popularity         -0.313674         -0.038221 -0.226610      0.255474
#
#                   Loudness(in db)  Liveness  Length(seconds)  Speechiness  \
# Unnamed: 0               0.126483  0.205656        -0.160972     0.006643
# ...

# %%
df1=df.corr()

# %%
df1.to_excel("corr.xlsx")
